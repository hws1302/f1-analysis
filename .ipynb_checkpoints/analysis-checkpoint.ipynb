# %% [markdown]
# # F1 Analysis - What makes a boring track?
#
# main aims:
# - quantify what is a boring track based on overtakes
# - this most crudely be change in position from quali
# - then add in number of times per race that position changes
# - then take into account people crashing out
# - startng in 2021 and then branching out to earlier seasons and seeing if tracks are consistently boring

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# first we must do some joins to import data for a single track... we can find the raceID for 2021 races

df = pd.read_csv('data/races.csv')

df[df.year == 2021].head()
# Out:
#       raceId  year  round  circuitId                       name        date  \
# 1035    1053  2021      2         21  Emilia Romagna Grand Prix  2021-04-18
# 1037    1052  2021      1          3         Bahrain Grand Prix  2021-03-28
# 1038    1051  2021     20         78           Qatar Grand Prix  2021-11-21
# 1039    1054  2021      3         75      Portuguese Grand Prix  2021-05-02
# 1040    1055  2021      4          4         Spanish Grand Prix  2021-05-09
#
#           time                                                url
# 1035  13:00:00  http://en.wikipedia.org/wiki/2021_Emilia_Romag...
# 1037  15:00:00  https://en.wikipedia.org/wiki/2021_Bahrain_Gra...
# 1038  14:00:00  http://en.wikipedia.org/wiki/2021_Qatar_Grand_...
# 1039  14:00:00  http://en.wikipedia.org/wiki/2021_Portuguese_G...
# 1040  13:00:00  http://en.wikipedia.org/wiki/2021_Spanish_Gran...

# %%
# lets first use the Qatar GP (random choice) which has raceId of 1053
# we need to import both qualifying and results to see the difference here 
# luckily these are both in the results.csv file

df_results_qatar = pd.read_csv('data/results.csv')

df_results_qatar = df_results[df_results.raceId == 1053]

df_results_qatar
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 24980     24986    1053       830              9     33     3        1
# 24981     24987    1053         1            131     44     1        2
# 24982     24988    1053       846              1      4     7        3
# 24983     24989    1053       844              6     16     4        4
# 24984     24990    1053       832              6     55    11        5
# 24985     24991    1053       817              1      3     6        6
# 24986     24992    1053       842            213     10     5        7
# 24987     24993    1053       840            117     18    10        8
# 24988     24994    1053       839            214     31     9        9
# 24989     24995    1053         4            214     14    15       10
# 24990     24996    1053       815              9     11     2       11
# 24991     24997    1053       852            213     22    20       12
# ...

# %%
# first lets see the difference in position for Hamilton with driverId 1, who started pole 

driverId = 1

grid = df_results_qatar.loc[df_results_qatar['driverId']==1]['grid']
finish = df_results_qatar.loc[df_results_qatar['driverId']==1]['position']

# here we can see that Hamilton finished one position below that of his grid position 
int(grid) - int(finish)
# Out:
# -1

# %%
variance = 0

for i in range(0,17):
    grid = df_results_qatar.loc[df_results_qatar['resultId']==(24986 + i)]['grid']
    finish = df_results_qatar.loc[df_results_qatar['resultId']==(24986 + i)]['position']

    variance += (int(grid) - int(finish))**2
    
variance = variance/(len(df_results) -1)

# here we can see each driver (that finished the race) changed, on average, 4.91 positions sounds about right...  
math.sqrt(variance)
# Out:
# 5.057563382541147

# %%
# the above method is great but in python why do it someone else can do it for you?
# here we have used the numpy standard deviation -> but have also counting retired drivers too

np.std(df_results_qatar['grid'] - df_results_qatar['positionOrder'])
# Out:
# 5.755649398634353

# %%
# how does this compare to Monaco, a track notorious for hard overtakes
# Monaco has a raceId of 1056

df_results_monaco = pd.read_csv('data/results.csv')

df_results_monaco = df_results_monaco[df_results_monaco.raceId == 1056]

df_results_monaco
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 25040     25047    1056       832              6     55     4        2
# 25041     25046    1056       830              9     33     2        1
# 25042     25048    1056       846              1      4     5        3
# 25043     25049    1056       815              9     11     9        4
# 25044     25050    1056        20            117      5     8        5
# 25045     25051    1056       842            213     10     6        6
# 25046     25052    1056         1            131     44     7        7
# 25047     25053    1056       840            117     18    13        8
# 25048     25054    1056       839            214     31    11        9
# 25049     25055    1056       841             51     99    10       10
# 25050     25056    1056         8             51      7    14       11
# 25051     25057    1056       817              1      3    12       12
# ...

# %%
# here we see a big downfall that if the drivers with good grid position crash out the position is massivley changed 

np.std(df_results_monaco['grid'] - df_results_monaco['positionOrder'])
# Out:
# 6.04979338490167

# %%
# we can remedy this by only counting the drivers that finished the race 
# we can take into account drivers who retired later on 

np.std(df_results_monaco['grid'][:18] - df_results_monaco['positionOrder'][:18])
# Out:
# 1.614937983749848

# %%
# we can make sure that we only count the drivers who finished more generally by removing any occurance of '\N'

df_results_monaco = df_results_monaco.loc[df_results_monaco.position != '\\N']

df_results_monaco
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 25040     25047    1056       832              6     55     4        2
# 25041     25046    1056       830              9     33     2        1
# 25042     25048    1056       846              1      4     5        3
# 25043     25049    1056       815              9     11     9        4
# 25044     25050    1056        20            117      5     8        5
# 25045     25051    1056       842            213     10     6        6
# 25046     25052    1056         1            131     44     7        7
# 25047     25053    1056       840            117     18    13        8
# 25048     25054    1056       839            214     31    11        9
# 25049     25055    1056       841             51     99    10       10
# 25050     25056    1056         8             51      7    14       11
# 25051     25057    1056       817              1      3    12       12
# ...

# %%
# now we get the value of standard deviation that we want!

np.std(df_results_monaco['grid'] - df_results_monaco['positionOrder'])
# Out:
# 1.614937983749848

# %% [markdown]
# ## Graphing the standard deviation of Monaco over the past 20 years
#
# First task is to do this simple std as a proxy for race boringness and see how this changes over time

# %%
df = pd.read_csv('data/races.csv')

df_results = pd.read_csv('data/results.csv')

# %%
# now lets look how the standard deviation has changed over the past 20 years at monaco

df_results_monaco = df_results

df = df.loc[df.name == 'Monaco Grand Prix']
df = df.loc[df.year > 1999]
df = df.sort_values(by=['year'])

monaco_std = []

for i in range(1999,2022):
    pass
    
df = df.sort_values(by=['year'])

    
df_results_monaco[df.raceId == df['raceId'][163]]
    
#     print(df_results['grid'] - df_results['positionOrder'])
# Out:
# /var/folders/yr/nz2d8_8n42g11zxgd7yjxhq40000gn/T/ipykernel_3558/2308634584.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_results_monaco[df.raceId == df['raceId'][163]]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/yr/nz2d8_8n42g11zxgd7yjxhq40000gn/T/ipykernel_3558/2308634584.py in <module>
#      15
#      16
# ---> 17 df_results_monaco[df.raceId == df['raceId'][163]]
#      18
#      19 #     print(df_results['grid'] - df_results['positionOrder'])
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ...

# %% [markdown]
# More things to add:
# - graph showing the overtaking at main tracks over x years (Monaco, Monza, Silverstone, Brazil, Australia, Spa)
# - Look at the overtakes at a single track over x years and see how this correlates with the weather (e.g. are wet tracks harder to overtake on?)
# - are laps times normally distributed (inbetween pits) maybe lognormal or something?

# %%
df
# Out:
#       raceId  year  round  circuitId               name        date      time  \
# 163      164  2000      7          6  Monaco Grand Prix  2000-06-04        \N
# 146      147  2001      7          6  Monaco Grand Prix  2001-05-27        \N
# 129      130  2002      7          6  Monaco Grand Prix  2002-05-26        \N
# 113      114  2003      7          6  Monaco Grand Prix  2003-06-01        \N
# 94        95  2004      6          6  Monaco Grand Prix  2004-05-23        \N
# 75        76  2005      6          6  Monaco Grand Prix  2005-05-22  14:00:00
# 58        59  2006      7          6  Monaco Grand Prix  2006-05-28  14:00:00
# 39        40  2007      5          6  Monaco Grand Prix  2007-05-27  12:00:00
# 22        23  2008      6          6  Monaco Grand Prix  2008-05-25  12:00:00
# 5          6  2009      6          6  Monaco Grand Prix  2009-05-24  12:00:00
# 341      342  2010      6          6  Monaco Grand Prix  2010-05-16  12:00:00
# ...
